# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas import DataFrame
from sklearn.datasets import load_boston

# %%
boston=load_boston()

# %%
df = DataFrame(boston.data, columns=boston.feature_names)

# %%
df ["PRICE"]=np.array(boston.target)

# %%
df
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0  242.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0  311.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0  311.0
# ...

# %%
sns.set()
#背景変更
sns.set_style("darkgrid", {'grid.linestyle': '--'})
#大きさ(スケール変更)
sns.set_context("paper")

# %%
sns.jointplot(x="RM", y="PRICE", data=df, kind="scatter", size=6, ratio=4, space=0, color="g")

# %%
plt.show()

# %%
sns.jointplot(x="RM", y="PRICE", data=df, kind="hex")

# %%
plt.show()

# %%
sns.jointplot(x="RM", y="PRICE", data=df, kind="reg")

# %%
plt.show()

# %%
sns.jointplot(x="RM", y="PRICE", data=df, kind="resid")

# %%
plt.show()

# %%
sns.jointplot(x="RM", y="PRICE", data=df, kind="kde")

# %%
plt.show()

# %%
sns.distplot(df["PRICE"], kde=True, rug=True, bins=30) 
plt.xlabel('Price in $1,000s')
# Out:
# Text(0.5,0,'Price in $1,000s')

# %%
plt.show()

# %%
sns.pairplot(df[["RM", "PRICE"]])

# %%
plt.show()

# %%
sns.pairplot(df)

# %%
plt.show()

# %%
#ここからはScikit-learnでだしたものでグラフを作ります。(目的は既に達成してます)

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  PRICE
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(df.loc[:,['RM']].values, df.loc[:,'PRICE'].values)

y_predicted = lr.predict(df.loc[:,['RM']].values)

# %%
plt.plot(df.loc[:,['RM']].values, df.loc[:,'PRICE'].values, 'o')

plt.title('Linear Regression')
#plt.plot(boston.data, boston.data, label='actual: y = x')
plt.plot(df.loc[:,['RM']].values, y_predicted, label='predicted: y = %.4f + %.4fx' % (lr.intercept_, lr.coef_))
plt.legend(loc=2)

# %%
plt.show()

# %%
plt.savefig('regression.png')

# %%
# matplotlibをインポート
import matplotlib.pyplot as plt

sns.set()
#背景変更
sns.set_style("darkgrid", {'grid.linestyle': '--'})
#大きさ(スケール変更)
sns.set_context("paper")

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas import DataFrame
from sklearn.datasets import load_boston

# %%
sns.set()
#背景変更
sns.set_style("darkgrid", {'grid.linestyle': '--'})
#大きさ(スケール変更)
sns.set_context("paper")

# %%
sns.regplot(x="RM", y="PRICE", data=df, color="green")
plt.show()

# %%
sns.regplot(x="RM", y="PRICE", data=df, ci=50)
plt.show()

# %%
sns.regplot(x="RM", y="PRICE", data=df, scatter=False)
plt.show()

# %%
sns.set()
#背景変更
sns.set_style("darkgrid", {'grid.linestyle': '--'})
#大きさ(スケール変更)
sns.set_context("paper")

#sns.set_style('ticks')
fig, ax = plt.subplots()
fig.set_size_inches(18.5, 10.5)

sns.regplot(x="RM", y="PRICE", ax=ax,  data=df , scatter_kws={"s": 200},   fit_reg=False)
#plt.show()
plt.savefig('scatter.png')

# %%
sns.regplot(x="RM", y="PRICE", data=df, fit_reg=False)
plt.savefig('scatter.png')

# %%
sns.regplot(x="RM", y="PRICE", data=df, order=1)

# %%
#here is unsccessfull

'''
==============
3D scatterplot
==============

Demonstration of a basic scatterplot in 3D.
'''

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
for c, m, zlow, zhigh in [('g', 'o', -30, -5)]:
    xs = data2[:,0]
    ys = data2[:,1]
    zs = target2
    ax.scatter(xs, ys, zs, c=c, marker=m)

ax.set_xlabel('Crime')
ax.set_ylabel('Room number')
ax.set_zlabel('Price')
plt.savefig('scatter3d.png')
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-661e1b7ff4e1> in <module>()
#      17 # defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
#      18 for c, m, zlow, zhigh in [('g', 'o', -30, -5)]:
# ---> 19     xs = data2[:,0]
#      20     ys = data2[:,1]
#      21     zs = target2
#
# NameError: name 'data2' is not defined
